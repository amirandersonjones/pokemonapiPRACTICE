# %% [markdown]
# # APIs
#
# #### What are they and how do we use them
#
# <p> API stands for application programming interface - what an API actually does is provide a way for different servers, devices, and applications to send information back and forth in a commonly understood structure. </p>
#
# <p> So using an api, we can send data from an application written in one programming language to an application written in another programming language on a different server, and both applications can understand that data. </p>

# %% [markdown]
# <p> Its kind of like the kitchen in a restaurant -> they take the unprepared food items, chop them up, cook them, and lay them out nicely presented on a plate for the customers to consume as they please. </p>
#
# <p> APIs use data formats that can be understood by multiple programming languages -> the most common one we will use is called JSON data (JavaScript Object Notation) </p>

# %%
import requests as r # often requests is imported under the alias r
result = r.get('https://pokeapi.co/api/v2/pokemon/charmander')
print(type(result))
print(result)
print(result.encoding)
print(result.status_code)
print(result.content) # just shows us what the computer currently has - a bunch of bytes
print(result.json()) # converts the bytes into a dictionary
# Out:
# <class 'requests.models.Response'>
# <Response [200]>
# utf-8
# 200
# ...

# %%
# Check Status Code
# the status code attribute of the Response object is an integer describing what happened with your request
# 200 - OK - everything went well
# 404 - not found
# 403 - forbidden (improper authorization)

# https://developer.mozilla.org/en-US/docs/Web/HTTP/Status

# 200s - positive responses
# 400s - client-side errors (you did something wrong)
# 500s - server-side errors (something in the API is broken)
print(result.status_code)
# Out:
# 200

# %%
# access the data that we're being sent
data = result.json()
print(type(data))
data['name']
# Out:
# <class 'dict'>
# 'charmander'

# %%
# In-Class Exercise #1
# From this API Endpoint: 'https://pokeapi.co/api/v2/pokemon/entei'
# Access the string 'emerald' thats located somewhere within game_indices
pika = r.get('https://pokeapi.co/api/v2/pokemon/pikachu')
print(type(pika))
pika = pika.json()
print(type(pika))

# print 'emerald'
print(pika['game_indices'][5]['version']['name'])
# print 'sapphire'
print(pika['game_indices'][4]['version']['name'])
# print 'ruby'
print(pika['game_indices'][3]['version']['name'])
# Out:
# <class 'requests.models.Response'>
# <class 'dict'>
# crystal
# silver
# gold

# %%
# What are the names of all of the Pokemon games that Entei is in?
print(type(entei['game_indices']))
# I want a list of the names of every game Entei is in.
entei_games = []
# Well, if I can do it for one piece of the data,
# entei['game_indices'][5]['version']['name']

# I can do it for all similarly structured data
for game in entei['game_indices']:
    entei_games.append(game['version']['name'])
    
print(entei_games)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16580/3732549334.py in <module>
#       1 # What are the names of all of the Pokemon games that Entei is in?
# ----> 2 print(type(entei['game_indices']))
#       3 # I want a list of the names of every game Entei is in.
#       4 entei_games = []
#       5 # Well, if I can do it for one piece of the data,
#
# NameError: name 'entei' is not defined

# %%
# End goal structure for the basic version of the assignment:

# Goal is to make 20 pokemon
# Each pokemon is a dictionary
{
    'name': 'spheal',
    'weight': 540,
    'abilities': ['ice beam', 'rain'],
    'types': ['ice', 'water']
}


# after you make all the individual pokemon
# put them in a dictionary of lists based on type
{
    'Fire': [{
        'name': 'spheal',
        'weight': 540,
        'abilities': ['ice beam', 'rain'],
        'types': ['ice', 'water']
        },
        {'name': 'spheal',
        'weight': 540,
        'abilities': ['ice beam', 'rain'],
        'types': ['ice', 'water']
         }
    ],
    'Flying': [ ... ],
    'Water': [{
    'name': 'spheal',
    'weight': 540,
    'abilities': ['ice beam', 'rain'],
    'types': ['ice', 'water']
}]
}

# %%
#You will be indexing into the giant print(charmander_data) json object (i.e., dictionary) and getting 
#all the data you want from it.

#You will then make your own dictionary containing 20 items.

# for a list []. You need to bracket in with an index value (i.e., 0 or some other integer)

#charmander_data[0] or charmander_data[1]
#Something like that

#And then when you see the curly brackets,A.K.A. a dictionary,you index in with a string corresponding to a 
#dictionary "key"
#charmander_data['abilities']

# %%
import requests as r #import in the tool that allows us to get api data
result = r.get('https://pokeapi.co/api/v2/pokemon/riolu')#access the data from the api via a link
print(result.status_code) #check to see if we actually got the data

print(result.json())
print(['type'])
# Out:
# 200
# ...

# %%
msg= '\tThis program will give you information about 20 selected pokemon.'#tell the user what the program does
print(msg.title())


print("\n\t-----------------Welcome to the Poke Menu-----------------")#greet user
print("\nHere is a list of Pokemon from which you may choose to add to your cart\n")

poke_cart= {} #create a cart for customer to buy a pokemon in order to view their information
quantity=1

#pokemon dictionary
def build_pokemon(name, weight, abilities, type_of_pokemon):
    """Return a dictionary of information about a pokemon."""
    formatted_pokemon= {'name': name, 'weight': weight, 'abilities':abilities, 'type_of_pokemon':type_of_pokemon}
    return formatted_pokemon
pokemon1= build_pokemon('charmander', 85, 'blaze/solarpower', 'fire')
print(f" Charmander {pokemon1}")
pokemon2= build_pokemon('pikachu', 60, 'lightening','electric' )
print(f" Pikachu {pokemon2}")
pokemon3=build_pokemon('ditto' ,40 ,'limber/imposter', 'normal')
print(f" Ditto {pokemon3}")
pokemon4=build_pokemon('charizard' ,20 ,'blaze/solarpower', 'fire/flying')
print(f" Charizard {pokemon4}")
pokemon5=build_pokemon('lucario' ,540 ,'limber/imposter', 'steel/fighting')
print(f" Lucario {pokemon5}")
pokemon6=build_pokemon('piplup' ,40 ,'limber/imposter', 'normal')
print(f" Piplup {pokemon6}")
pokemon7=build_pokemon('snorlax' ,4600 ,'immunity/thickfat/gluttony', 'normal')
print(f" Snorlax {pokemon7}")
pokemon8=build_pokemon('garchomp' ,950 ,'sandveil/roughskin', 'ground/dragon')
print(f" Garchomp {pokemon8}")
pokemon9=build_pokemon('mew' ,40 ,'synchronize', 'psychic')
print(f"Mew {pokemon9}")
pokemon10=build_pokemon('squirtle' ,90 ,'torrent/raindish', 'water')
print(f" Squirtle {pokemon10}")
pokemon11=build_pokemon('dialga' ,6830 ,'pressure/telepathy', 'steel/dragon')
print(f" Dialga {pokemon11}")
pokemon12=build_pokemon('gible' ,205 ,'sandveil/roughskin', 'dragon')
print(f" Gible {pokemon12}")
pokemon13=build_pokemon('jigglypuff' ,55 ,'cute-charm/competitive', 'fairy/normal')
print(f" Jigglypuff {pokemon13}")
pokemon14=build_pokemon('budew' ,55 ,'poisonpoint/leafguard/naturalcure', 'grass/poison')
print(f" Budew {pokemon14}")
pokemon15=build_pokemon('ditto' ,40 ,'limber/imposter', 'normal')
print(f" Ditto {pokemon15}")
pokemon16=build_pokemon('jynx' ,406 ,'oblivious/forewarn/dryskin', 'psychic/ice')
print(f" Jynx {pokemon16}")
pokemon17=build_pokemon('torterro' ,3100 ,'overgrown/shellarmor', 'grass/ground')
print(f" Torterro {pokemon17}")
pokemon18=build_pokemon('glaceon' ,259 ,'snowcloak/icebody', 'ice')
print(f" Glaceon {pokemon18}")
pokemon19=build_pokemon('riolu' ,202 ,'steadfast/prankster/inner-focus', 'fighting')
print(f" Riolu {pokemon19}")
pokemon20=build_pokemon('pichu' ,20 ,'static/lighteningrod', 'electric')
print(f" Pichu {pokemon20}")

cart_open=True #on switch for my program
#while dictionary_open == True:
    #ask=input("Would you like to add a pokemon to your cart/show your pokemon/or quit?")
    #clear_output()
    #if ask=='add':
    #name_of_pokemon=input("Which pokemon would you like to add to your cart?")
    #clear_output()
    #poke_cart[name_of_pokemon]=quantity
    #elif ask == 'show':
        #print(poke_cart)
    #elif ask == 'quit':
        #cart_open == False
        #break
    #else:
        #pass
# Out:
# 	This Program Will Give You Information About 20 Selected Pokemon.
#
# 	-----------------Welcome to the Poke Menu-----------------
#
# Here is a list of Pokemon from which you may choose to add to your cart
#
#  Charmander {'name': 'charmander', 'weight': 85, 'abilities': 'blaze/solarpower', 'type_of_pokemon': 'fire'}
#  Pikachu {'name': 'pikachu', 'weight': 60, 'abilities': 'lightening', 'type_of_pokemon': 'electric'}
#  Ditto {'name': 'ditto', 'weight': 40, 'abilities': 'limber/imposter', 'type_of_pokemon': 'normal'}
#  Charizard {'name': 'charizard', 'weight': 20, 'abilities': 'blaze/solarpower', 'type_of_pokemon': 'fire/flying'}
#  Lucario {'name': 'lucario', 'weight': 540, 'abilities': 'limber/imposter', 'type_of_pokemon': 'steel/fighting'}
#  Piplup {'name': 'piplup', 'weight': 40, 'abilities': 'limber/imposter', 'type_of_pokemon': 'normal'}
#  Snorlax {'name': 'snorlax', 'weight': 4600, 'abilities': 'immunity/thickfat/gluttony', 'type_of_pokemon': 'normal'}
# ...

# %%
# remember that string concatenation is a thing and/or that f-strings work here

# %%
import requests as r
# Instead of Making a Pokemon Dictionary, I want to make pokemon objects
# I want to store those pokemon objects in a dictionary where the key is the pokemon's name
# {
# 'grovyle' : <pokemon_object for grovyle @ 0x304180sflk31sj>
# }
# I want to be able to pass a dictionary made from the API call .json() data into the __init__() of Pokemon class
# and have the pokemon's attributes be filled out from there

# let me lay out my skeleton code
# pokemon object is gonna have the same attributes
    # name=str, abilities=[], types=[], weight=int
# pokemon object methods
    # display that prints our pokemon's info nice and pretty prettily? fancy-lookin.

# second class pokedex
    # 1 attribute - the dictionary of all the pokemon
    
    # 3 methods
        # 1 create pokemon -> take in a list of pokemon names, and fill up our objects/dictionary
        # 2 display function - to show all the pokemon
        # 3 searching function to display based on the pokemon type asked for
        
        
        
        
# pokemon objects





# pokedex objects

# %%
# Driver Code
